# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\k agnes\anaconda3\anaconda3\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns

# %%
data=pd.read_csv("iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
s_wid = data["SepalWidthCm"]
s_wid
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
a = s_wid.mean()

# %%
a
# Out:
# np.float64(3.0540000000000003)

# %%
int(s_wid.mean())
# Out:
# 3

# %%
b=s_wid.std()

# %%
b
# Out:
# 0.4335943113621737

# %%
s_wid.median()
# Out:
# 3.0

# %%
s_wid.var()
# Out:
# 0.18800402684563763

# %%
s_wid.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: SepalWidthCm, Length: 150, dtype: bool

# %%
s_wid.sum()
# Out:
# np.float64(458.1)

# %%
s_wid.hist(figsize=(12,8), bins=6)
# Out:
# <Axes: >

# %%
from scipy.stats import skew, kurtosis, norm

# %%
s_wid.skew()
# Out:
# np.float64(0.3340526621720866)

# %%
s_wid.hist(figsize=(8,6), density = True, bins = 6)
x = np.linspace(s_wid.min(), s_wid.max(), 100)
y = norm.pdf(x,a,b)
plt.plot(x,y)
plt.show()

# %%
p_len = data["PetalLengthCm"]
p_len
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
c = p_len.mean()

# %%
c
# Out:
# np.float64(3.758666666666666)

# %%
d = p_len.std()

# %%
d
# Out:
# 1.7644204199522617

# %%
from scipy.stats import norm

# %%
p_len.hist(figsize=(8,6), density = True, bins = 6)
x = np.linspace(p_len.min(), p_len.max(), 100)
y = norm.pdf(x,c,d)
plt.plot(x,y)
plt.show()

# %%
data1 = data.drop("Species", axis=1)

# %%
data2 = data1.drop("Id",axis=1)

# %%
data2
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
data2.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
