# %%
# Parent Class
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
    def move(self):
        pass  
    def is_active(self):
        return False   
# Car Class
class Car(Vehicle):
    def __init__(self, brand, model, fuel_type):
        super().__init__(brand, model)
        self.fuel_type = fuel_type

    def move(self):
        print("Car is driving on the road")

    def is_active(self):
        return True   
# Plane Class
class Plane(Vehicle):
    def __init__(self, brand, model, altitude):
        super().__init__(brand, model)
        self.altitude = altitude
    def move(self):
        print(f"Plane is flying at {self.altitude} feet")
    def is_active(self):
        return self.altitude > 10000
# Boat Class
class Boat(Vehicle):
    def __init__(self, brand, model, capacity):
        super().__init__(brand, model)
        self.capacity = capacity
    def move(self):
        print(f"Boat is sailing with {self.capacity} passengers")
    def is_active(self):
        return self.capacity > 0
# Drone Class
class Drone(Vehicle):
    def __init__(self, brand, model, battery):
        super().__init__(brand, model)
        self.battery = battery
    def move(self):
        if self.battery > 20:
            print("Drone is hovering")
        else:
            print("Drone battery low, cannot fly")
    def is_active(self):
        return self.battery > 20

car1 = Car("Tesla", "ModelS", "Electric")
plane1 = Plane("Boeing", "777", 35000)
boat1 = Boat("Yamaha", "WaveRider", 6)
drone1 = Drone("DJI", "Mini3", 15)

for v in fleet:
    v.move()
active_count = 0
for v in fleet:
    if v.is_active():     
        active_count += 1
print("Active Vehicles:", active_count)
# Out:
# Car is driving on the road
# Plane is flying at 35000 feet
# Boat is sailing with 6 passengers
# Drone battery low, cannot fly
# Active Vehicles: 3
