# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Instagram_Analytics - final.csv")
df
# Out:
#          post_id upload_date media_type   likes  comments  shares  saves  \
# 0      IG0000001     25:23.0       Reel   31627      7559    4530   6393
# 1      IG0000002     25:23.0      Photo   63206      3490    1680   6809
# 2      IG0000003     25:23.0       Reel   94373      3727    1761   8367
# 3      IG0000004     25:23.0       Reel  172053      7222    2875   9290
# 4      IG0000005     25:23.0      Video   99646      2703    4444   9746
# ...          ...         ...        ...     ...       ...     ...    ...
# 29993  IG0029995     25:23.0      Video   46046      8354    3847  11095
# 29994  IG0029996     25:23.0   Carousel   67711      3266     458  12380
# 29995  IG0029997     25:23.0      Photo   52326      7328    3687   7619
# 29996  IG0029998     25:23.0   Carousel  158113      5890    2573   6329
# 29997  IG0029999     25:23.0      Photo   76368      7115    4603  11715
#
#          reach  impressions  caption_length  hashtags_count  followers_gained  \
# ...

# %%
df.head()
# Out:
#      post_id upload_date media_type   likes  comments  shares  saves    reach  \
# 0  IG0000001     25:23.0       Reel   31627      7559    4530   6393   615036
# 1  IG0000002     25:23.0      Photo   63206      3490    1680   6809  1237071
# 2  IG0000003     25:23.0       Reel   94373      3727    1761   8367  1127470
# 3  IG0000004     25:23.0       Reel  172053      7222    2875   9290   764030
# 4  IG0000005     25:23.0      Video   99646      2703    4444   9746     7004
#
#    impressions  caption_length  hashtags_count  followers_gained  \
# 0      1007750            1340               3               899
# 1      1345900            1351              20               805
# 2      1305369             242              24               758
# 3       897874             446              11               402
# 4       495406            1905               8               155
#
#   traffic_source  engagement_rate content_category
# 0      Home Feed             4.97       Technology
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29998 entries, 0 to 29997
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   post_id           29998 non-null  object
#  1   upload_date       29998 non-null  object
#  2   media_type        29998 non-null  object
#  3   likes             29998 non-null  int64
#  4   comments          29998 non-null  int64
#  5   shares            29998 non-null  int64
#  6   saves             29998 non-null  int64
#  7   reach             29998 non-null  int64
#  8   impressions       29998 non-null  int64
#  9   caption_length    29998 non-null  int64
#  10  hashtags_count    29998 non-null  int64
#  11  followers_gained  29998 non-null  int64
#  12  traffic_source    29998 non-null  object
#  13  engagement_rate   29998 non-null  float64
#  14  content_category  29998 non-null  object
# dtypes: float64(1), int64(9), object(5)
# memory usage: 3.4+ MB

# %%
df.describe()
# Out:
#                likes      comments        shares         saves         reach  \
# count   29998.000000  29998.000000  29998.000000  29998.000000  2.999800e+04
# mean    99913.466964   5017.867958   2502.896993   7490.118608  9.965498e+05
# std     57906.764653   2888.414141   1448.342025   4352.619373  5.777967e+05
# min         7.000000      0.000000      0.000000      0.000000  1.650000e+02
# 25%     49753.500000   2531.000000   1246.000000   3690.250000  4.936785e+05
# 50%     99582.000000   5042.000000   2497.500000   7482.500000  9.921495e+05
# 75%    150225.000000   7518.000000   3768.000000  11294.000000  1.494821e+06
# max    200000.000000  10000.000000   5000.000000  15000.000000  1.999865e+06
#
#         impressions  caption_length  hashtags_count  followers_gained  \
# count  2.999800e+04    29998.000000    29998.000000      29998.000000
# mean   1.246658e+06     1103.142209       14.887793        502.161544
# ...

# %%
df.isnull().sum()
# Out:
# post_id             0
# upload_date         0
# media_type          0
# likes               0
# comments            0
# shares              0
# saves               0
# reach               0
# impressions         0
# caption_length      0
# hashtags_count      0
# followers_gained    0
# traffic_source      0
# engagement_rate     0
# content_category    0
# dtype: int64

# %%
performance_summary = df[['likes','comments','shares','saves','reach','impressions']].describe()
performance_summary
# Out:
#                likes      comments        shares         saves         reach  \
# count   29998.000000  29998.000000  29998.000000  29998.000000  2.999800e+04
# mean    99913.466964   5017.867958   2502.896993   7490.118608  9.965498e+05
# std     57906.764653   2888.414141   1448.342025   4352.619373  5.777967e+05
# min         7.000000      0.000000      0.000000      0.000000  1.650000e+02
# 25%     49753.500000   2531.000000   1246.000000   3690.250000  4.936785e+05
# 50%     99582.000000   5042.000000   2497.500000   7482.500000  9.921495e+05
# 75%    150225.000000   7518.000000   3768.000000  11294.000000  1.494821e+06
# max    200000.000000  10000.000000   5000.000000  15000.000000  1.999865e+06
#
#         impressions
# count  2.999800e+04
# mean   1.246658e+06
# std    5.970996e+05
# min    5.107000e+03
# 25%    7.469372e+05
# 50%    1.240986e+06
# 75%    1.749265e+06
# max    2.497940e+06

# %%
#overall average engagement rate
df['engagement_rate'].mean()
# Out:
# np.float64(14.419566304420295)

# %%
media_engagement = df.groupby('media_type')['engagement_rate'].mean().reset_index()
media_engagement
# Out:
#   media_type  engagement_rate
# 0   Carousel        14.323362
# 1      Photo        14.191059
# 2       Reel        14.541715
# 3      Video        14.619641

# %%
plt.figure()
sns.barplot(data=media_engagement , x='media_type' , y='engagement_rate')
plt.title("Average Engagement Rate by Media Type")
plt.show()

# %%
content_engagement=df.groupby('content_category')['engagement_rate'].mean().reset_index()
content_engagement
# Out:
#   content_category  engagement_rate
# 0           Beauty        15.667761
# 1           Comedy        14.396149
# 2          Fashion        14.523533
# 3          Fitness        13.948752
# 4             Food        13.988711
# 5        Lifestyle        14.692105
# 6            Music        14.488062
# 7      Photography        14.816511
# 8       Technology        13.927650
# 9           Travel        13.757692

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.pie(df['engagement_rate'], labels=df['content_category'], autopct='%1.1f%%')
plt.title("Engagement Rate by Content Category")
plt.show()

# %%
plt.figure()
plt.pie(
    media_engagement['engagement_rate'],
    labels=media_engagement['media_type'],
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Average Engagement Rate by Media Type")
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='caption_length', y='engagement_rate')
plt.title("Caption length and Engagement Rate")
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='hashtags_count', y='reach',)
plt.title("Hashtags count vs Reach")
plt.show()

# %%
traffic_analysis = df.groupby('traffic_source')[['engagement_rate','followers_gained']].mean().reset_index()
traffic_analysis

# %%
traffic_analysis.plot(kind='bar',x='traffic_source')
plt.title("Traffic source vs Engagement & Followers Gained")
plt.show()

# %%
Insights:

Reels and videos show higher engagement rates than static images.
Medium-length captions generate better engagement.
Posts with moderate hashtag counts achieve higher reach.
Certain traffic sources contribute more to follower growth.
